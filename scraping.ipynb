# %% [markdown]
# ### Scraping Ami By Tag

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
import random
from concurrent.futures import ThreadPoolExecutor, as_completed
from requests.adapters import HTTPAdapter
from urllib3.util.retry import Retry
import urllib3

urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)

# ===============================
# GLOBAL CONFIG
# ===============================

HEADERS = {
    "User-Agent": (
        "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
        "AppleWebKit/537.36 (KHTML, like Gecko) "
        "Chrome/143.0.0.0 Safari/537.36"
    )
}

# ===============================
# MAIN FUNCTION
# ===============================

def scrape_ami_tag(tag_name, tag_slug, max_workers=10):
    """
    Scrape all articles from an AMI tag and save to CSV.

    Parameters
    ----------
    tag_name : str
        Human-readable tag name (e.g. 'Santé')
    tag_slug : str
        Tag slug used in URL (e.g. 'sante')
    max_workers : int
        Number of threads for article body fetching
    """

    BASE_URL = f"https://ami.mr/fr/archives/tag/{tag_slug}/page/{{}}"

    # ---- Session with retries ----
    session = requests.Session()
    retry = Retry(total=3, backoff_factor=0.5)
    adapter = HTTPAdapter(max_retries=retry)
    session.mount("https://", adapter)
    session.mount("http://", adapter)

    articles = []

    # ===============================
    # FETCH ARTICLE BODY
    # ===============================

    def fetch_article_body(link):
        if not link:
            return None
        try:
            resp = session.get(link, headers=HEADERS, timeout=10, verify=False)
            soup = BeautifulSoup(resp.text, "html.parser")
            content_div = soup.find(
                "div", class_="entry-content clearfix single-post-content"
            )

            if content_div:
                first_p = content_div.find("p")
                if first_p:
                    for br in first_p.find_all("br"):
                        br.replace_with(" ")
                    time.sleep(random.uniform(0.3, 1.0))
                    return first_p.get_text(" ", strip=True)

        except Exception as e:
            print(f"⚠ Error fetching body: {link} -> {e}")

        return None

    # ===============================
    # SCRAPE PAGINATION
    # ===============================

    page = 1
    while True:
        url = BASE_URL.format(page)
        print(f"\n🔎 Scraping tag '{tag_name}' | page {page}")

        try:
            response = session.get(url, headers=HEADERS, timeout=10, verify=False)

            if response.status_code != 200:
                print("✔ No more pages. Stopping.")
                break

            soup = BeautifulSoup(response.text, "html.parser")
            posts = soup.find_all("article")

            if not posts:
                print("✔ No articles found. Finished.")
                break

            page_articles = []

            for post in posts:
                title_tag = post.find("a", class_="post-url")
                time_tag = post.find("time")
                summary_tag = post.find("div", class_="post-summary")

                page_articles.append({
                    "tag": tag_name,
                    "title": title_tag.get_text(strip=True) if title_tag else None,
                    "url": title_tag["href"] if title_tag else None,
                    "datetime": time_tag["datetime"] if time_tag else None,
                    "summary": summary_tag.get_text(strip=True) if summary_tag else None,
                })

            # ---- Fetch article bodies in parallel ----
            print(f"➡ Fetching {len(page_articles)} article bodies...")
            with ThreadPoolExecutor(max_workers=max_workers) as executor:
                futures = {
                    executor.submit(fetch_article_body, art["url"]): i
                    for i, art in enumerate(page_articles)
                }
                for future in as_completed(futures):
                    idx = futures[future]
                    page_articles[idx]["article_body"] = future.result()

            articles.extend(page_articles)
            page += 1
            time.sleep(random.uniform(1, 2))

        except requests.RequestException as e:
            print(f"⚠ Request error on page {page}: {e}")
            time.sleep(2)

    # ===============================
    # SAVE TO CSV
    # ===============================

    df = pd.DataFrame(articles)
    df["datetime"] = pd.to_datetime(df["datetime"], errors="coerce")
    df = df.sort_values("datetime", ascending=False)

    if not df.empty:
        start_date = df["datetime"].max().strftime("%Y-%m-%d")
        end_date   = df["datetime"].min().strftime("%Y-%m-%d")
    else:
        start_date = end_date = "NA"

    filename = f"ami_Tag_{tag_slug}_{start_date}_to_{end_date}.csv"
    df.to_csv(filename, index=False, encoding="utf-8-sig")

    print(f"\n✅ Saved: {filename}")
    print(f"📌 Total articles scraped: {len(df)}")

    return df

# %% [markdown]
# ## Politique Tag

# %%
# Politique tag
df_politique = scrape_ami_tag("Politique", "politique")
# Out:
# 🔎 Scraping tag 'Politique' | page 1
# ➡ Fetching 10 article bodies...
#
# 🔎 Scraping tag 'Politique' | page 2
# ➡ Fetching 10 article bodies...
#
# 🔎 Scraping tag 'Politique' | page 3
# ➡ Fetching 10 article bodies...
#
# 🔎 Scraping tag 'Politique' | page 4
# ➡ Fetching 10 article bodies...
#
# 🔎 Scraping tag 'Politique' | page 5
# ➡ Fetching 10 article bodies...
#
# 🔎 Scraping tag 'Politique' | page 6
# ➡ Fetching 10 article bodies...
#
# 🔎 Scraping tag 'Politique' | page 7
# ➡ Fetching 10 article bodies...
# ⚠ Error fetching body: https://ami.mr/fr/archives/93029 -> HTTPSConnectionPool(host='ami.mr', port=443): Max retries exceeded with url: /fr/archives/93029 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='ami.mr', port=443): Read timed out. (read timeout=10)"))
# ⚠ Error fetching body: https://ami.mr/fr/archives/92957 -> HTTPSConnectionPool(host='ami.mr', port=443): Max retries exceeded with url: /fr/archives/92957 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='ami.mr', port=443): Read timed out. (read timeout=10)"))⚠ Error fetching body: https://ami.mr/fr/archives/93100 -> HTTPSConnectionPool(host='ami.mr', port=443): Max retries exceeded with url: /fr/archives/93100 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='ami.mr', port=443): Read timed out. (read timeout=10)"))
#
# ⚠ Error fetching body: https://ami.mr/fr/archives/93242 -> HTTPSConnectionPool(host='ami.mr', port=443): Max retries exceeded with url: /fr/archives/93242 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='ami.mr', port=443): Read timed out. (read timeout=10)"))
# ⚠ Error fetching body: https://ami.mr/fr/archives/93012 -> HTTPSConnectionPool(host='ami.mr', port=443): Max retries exceeded with url: /fr/archives/93012 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='ami.mr', port=443): Read timed out. (read timeout=10)"))
# ⚠ Error fetching body: https://ami.mr/fr/archives/93204 -> HTTPSConnectionPool(host='ami.mr', port=443): Max retries exceeded with url: /fr/archives/93204 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='ami.mr', port=443): Read timed out. (read timeout=10)"))
# ⚠ Error fetching body: https://ami.mr/fr/archives/93088 -> HTTPSConnectionPool(host='ami.mr', port=443): Max retries exceeded with url: /fr/archives/93088 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='ami.mr', port=443): Read timed out. (read timeout=10)"))
# ⚠ Error fetching body: https://ami.mr/fr/archives/93148 -> HTTPSConnectionPool(host='ami.mr', port=443): Max retries exceeded with url: /fr/archives/93148 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='ami.mr', port=443): Read timed out. (read timeout=10)"))
#
# 🔎 Scraping tag 'Politique' | page 8
# ➡ Fetching 10 article bodies...
#
# 🔎 Scraping tag 'Politique' | page 9
# ➡ Fetching 10 article bodies...
#
# 🔎 Scraping tag 'Politique' | page 10
# ➡ Fetching 10 article bodies...
#
# 🔎 Scraping tag 'Politique' | page 11
# ➡ Fetching 10 article bodies...
#
# 🔎 Scraping tag 'Politique' | page 12
# ➡ Fetching 10 article bodies...
#
# 🔎 Scraping tag 'Politique' | page 13
# ➡ Fetching 10 article bodies...
# ⚠ Error fetching body: https://ami.mr/fr/archives/90245 -> HTTPSConnectionPool(host='ami.mr', port=443): Max retries exceeded with url: /fr/archives/90245 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='ami.mr', port=443): Read timed out. (read timeout=10)"))⚠ Error fetching body: https://ami.mr/fr/archives/90551 -> HTTPSConnectionPool(host='ami.mr', port=443): Max retries exceeded with url: /fr/archives/90551 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='ami.mr', port=443): Read timed out. (read timeout=10)"))
# ⚠ Error fetching body: https://ami.mr/fr/archives/90689 -> HTTPSConnectionPool(host='ami.mr', port=443): Max retries exceeded with url: /fr/archives/90689 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='ami.mr', port=443): Read timed out. (read timeout=10)"))
# ⚠ Error fetching body: https://ami.mr/fr/archives/90537 -> HTTPSConnectionPool(host='ami.mr', port=443): Max retries exceeded with url: /fr/archives/90537 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='ami.mr', port=443): Read timed out. (read timeout=10)"))
# ⚠ Error fetching body: https://ami.mr/fr/archives/90538 -> HTTPSConnectionPool(host='ami.mr', port=443): Max retries exceeded with url: /fr/archives/90538 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='ami.mr', port=443): Read timed out. (read timeout=10)"))
#
#
# 🔎 Scraping tag 'Politique' | page 14
# ➡ Fetching 10 article bodies...
# ⚠ Error fetching body: https://ami.mr/fr/archives/90136 -> HTTPSConnectionPool(host='ami.mr', port=443): Max retries exceeded with url: /fr/archives/90136 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='ami.mr', port=443): Read timed out. (read timeout=10)"))
#
# 🔎 Scraping tag 'Politique' | page 15
# ⚠ Request error on page 15: HTTPSConnectionPool(host='ami.mr', port=443): Max retries exceeded with url: /fr/archives/tag/politique/page/15 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='ami.mr', port=443): Read timed out. (read timeout=10)"))
#
# 🔎 Scraping tag 'Politique' | page 15
# ⚠ Request error on page 15: HTTPSConnectionPool(host='ami.mr', port=443): Max retries exceeded with url: /fr/archives/tag/politique/page/15 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='ami.mr', port=443): Read timed out. (read timeout=10)"))
#
# 🔎 Scraping tag 'Politique' | page 15
# ⚠ Request error on page 15: HTTPSConnectionPool(host='ami.mr', port=443): Max retries exceeded with url: /fr/archives/tag/politique/page/15 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='ami.mr', port=443): Read timed out. (read timeout=10)"))
#
# 🔎 Scraping tag 'Politique' | page 15
# ⚠ Request error on page 15: HTTPSConnectionPool(host='ami.mr', port=443): Max retries exceeded with url: /fr/archives/tag/politique/page/15 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='ami.mr', port=443): Read timed out. (read timeout=10)"))
#
# 🔎 Scraping tag 'Politique' | page 15
# ⚠ Request error on page 15: HTTPSConnectionPool(host='ami.mr', port=443): Max retries exceeded with url: /fr/archives/tag/politique/page/15 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='ami.mr', port=443): Read timed out. (read timeout=10)"))
#
# 🔎 Scraping tag 'Politique' | page 15
# ⚠ Request error on page 15: HTTPSConnectionPool(host='ami.mr', port=443): Max retries exceeded with url: /fr/archives/tag/politique/page/15 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='ami.mr', port=443): Read timed out. (read timeout=10)"))
#
# 🔎 Scraping tag 'Politique' | page 15
# ⚠ Request error on page 15: HTTPSConnectionPool(host='ami.mr', port=443): Max retries exceeded with url: /fr/archives/tag/politique/page/15 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='ami.mr', port=443): Read timed out. (read timeout=10)"))
#
# 🔎 Scraping tag 'Politique' | page 15
# ⚠ Request error on page 15: HTTPSConnectionPool(host='ami.mr', port=443): Max retries exceeded with url: /fr/archives/tag/politique/page/15 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='ami.mr', port=443): Read timed out. (read timeout=10)"))
#
# 🔎 Scraping tag 'Politique' | page 15
# ➡ Fetching 10 article bodies...
# ⚠ Error fetching body: https://ami.mr/fr/archives/89777 -> HTTPSConnectionPool(host='ami.mr', port=443): Max retries exceeded with url: /fr/archives/89777 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='ami.mr', port=443): Read timed out. (read timeout=10)"))
#
# 🔎 Scraping tag 'Politique' | page 16
# ➡ Fetching 10 article bodies...
# ⚠ Error fetching body: https://ami.mr/fr/archives/89271 -> HTTPSConnectionPool(host='ami.mr', port=443): Max retries exceeded with url: /fr/archives/89271 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='ami.mr', port=443): Read timed out. (read timeout=10)"))
# ⚠ Error fetching body: https://ami.mr/fr/archives/89295 -> HTTPSConnectionPool(host='ami.mr', port=443): Max retries exceeded with url: /fr/archives/89295 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='ami.mr', port=443): Read timed out. (read timeout=10)"))
# ⚠ Error fetching body: https://ami.mr/fr/archives/89220 -> HTTPSConnectionPool(host='ami.mr', port=443): Max retries exceeded with url: /fr/archives/89220 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='ami.mr', port=443): Read timed out. (read timeout=10)"))
# ⚠ Error fetching body: https://ami.mr/fr/archives/89216 -> HTTPSConnectionPool(host='ami.mr', port=443): Max retries exceeded with url: /fr/archives/89216 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='ami.mr', port=443): Read timed out. (read timeout=10)"))
# ⚠ Error fetching body: https://ami.mr/fr/archives/89171 -> HTTPSConnectionPool(host='ami.mr', port=443): Max retries exceeded with url: /fr/archives/89171 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='ami.mr', port=443): Read timed out. (read timeout=10)"))
# ⚠ Error fetching body: https://ami.mr/fr/archives/89375 -> HTTPSConnectionPool(host='ami.mr', port=443): Max retries exceeded with url: /fr/archives/89375 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='ami.mr', port=443): Read timed out. (read timeout=10)"))
# ⚠ Error fetching body: https://ami.mr/fr/archives/89185 -> HTTPSConnectionPool(host='ami.mr', port=443): Max retries exceeded with url: /fr/archives/89185 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='ami.mr', port=443): Read timed out. (read timeout=10)"))
# ⚠ Error fetching body: https://ami.mr/fr/archives/89339 -> HTTPSConnectionPool(host='ami.mr', port=443): Max retries exceeded with url: /fr/archives/89339 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='ami.mr', port=443): Read timed out. (read timeout=10)"))
#
# 🔎 Scraping tag 'Politique' | page 17
# ⚠ Request error on page 17: HTTPSConnectionPool(host='ami.mr', port=443): Max retries exceeded with url: /fr/archives/tag/politique/page/17 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='ami.mr', port=443): Read timed out. (read timeout=10)"))
#
# 🔎 Scraping tag 'Politique' | page 17
# ⚠ Request error on page 17: HTTPSConnectionPool(host='ami.mr', port=443): Max retries exceeded with url: /fr/archives/tag/politique/page/17 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='ami.mr', port=443): Read timed out. (read timeout=10)"))
#
# 🔎 Scraping tag 'Politique' | page 17
# ⚠ Request error on page 17: HTTPSConnectionPool(host='ami.mr', port=443): Max retries exceeded with url: /fr/archives/tag/politique/page/17 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='ami.mr', port=443): Read timed out. (read timeout=10)"))
#
# 🔎 Scraping tag 'Politique' | page 17
# ➡ Fetching 10 article bodies...
#
# 🔎 Scraping tag 'Politique' | page 18
# ➡ Fetching 10 article bodies...
#
# 🔎 Scraping tag 'Politique' | page 19
# ➡ Fetching 10 article bodies...
#
# 🔎 Scraping tag 'Politique' | page 20
# ➡ Fetching 10 article bodies...
#
# 🔎 Scraping tag 'Politique' | page 21
# ➡ Fetching 10 article bodies...
#
# 🔎 Scraping tag 'Politique' | page 22
# ➡ Fetching 10 article bodies...
#
# 🔎 Scraping tag 'Politique' | page 23
# ➡ Fetching 10 article bodies...
#
# 🔎 Scraping tag 'Politique' | page 24
# ➡ Fetching 10 article bodies...
#
# 🔎 Scraping tag 'Politique' | page 25
# ➡ Fetching 10 article bodies...
#
# 🔎 Scraping tag 'Politique' | page 26
# ➡ Fetching 10 article bodies...
#
# 🔎 Scraping tag 'Politique' | page 27
# ➡ Fetching 10 article bodies...
#
# 🔎 Scraping tag 'Politique' | page 28
# ➡ Fetching 10 article bodies...
#
# 🔎 Scraping tag 'Politique' | page 29
# ➡ Fetching 10 article bodies...
#
# 🔎 Scraping tag 'Politique' | page 30
# ➡ Fetching 10 article bodies...
#
# 🔎 Scraping tag 'Politique' | page 31
# ➡ Fetching 10 article bodies...
#
# 🔎 Scraping tag 'Politique' | page 32
# ➡ Fetching 10 article bodies...
#
# 🔎 Scraping tag 'Politique' | page 33
# ➡ Fetching 10 article bodies...
#
# 🔎 Scraping tag 'Politique' | page 34
# ➡ Fetching 10 article bodies...
#
# 🔎 Scraping tag 'Politique' | page 35
# ➡ Fetching 10 article bodies...
# ⚠ Error fetching body: https://ami.mr/fr/archives/84075 -> HTTPSConnectionPool(host='ami.mr', port=443): Max retries exceeded with url: /fr/archives
(Caused by ReadTimeoutError("HTTPSConnectionPool(host='ami.mr', port=443): Read timed out. (read timeout=10)"))⚠ Error fetching body: https://ami.mr/fr/archives/33796 -> HTTPSConnectionPool(host='ami.mr', port=443): Max retries exceeded with url: /fr/archives/33796 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='ami.mr', port=443): Read timed out. (read timeout=10)"))
#
# ⚠ Error fetching body: https://ami.mr/fr/archives/33692 -> HTTPSConnectionPool(host='ami.mr', port=443): Max retries exceeded with url: /fr/archives/33692 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='ami.mr', port=443): Read timed out. (read timeout=10)"))
# ⚠ Error fetching body: https://ami.mr/fr/archives/33744 -> HTTPSConnectionPool(host='ami.mr', port=443): Max retries exceeded with url: /fr/archives/33744 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='ami.mr', port=443): Read timed out. (read timeout=10)"))⚠ Error fetching body: https://ami.mr/fr/archives/33750 -> HTTPSConnectionPool(host='ami.mr', port=443): Max retries exceeded with url: /fr/archives/33750 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='ami.mr', port=443): Read timed out. (read timeout=10)"))
#
# ⚠ Error fetching body: https://ami.mr/fr/archives/33802 -> HTTPSConnectionPool(host='ami.mr', port=443): Max retries exceeded with url: /fr/archives/33802 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='ami.mr', port=443): Read timed out. (read timeout=10)"))⚠ Error fetching body: https://ami.mr/fr/archives/33795 -> HTTPSConnectionPool(host='ami.mr', port=443): Max retries exceeded with url: /fr/archives/33795 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='ami.mr', port=443): Read timed out. (read timeout=10)"))
#
#
# 🔎 Scraping tag 'Politique' | page 223
# ➡ Fetching 10 article bodies...
# ⚠ Error fetching body: https://ami.mr/fr/archives/33643 -> HTTPSConnectionPool(host='ami.mr', port=443): Max retries exceeded with url: /fr/archives/33643 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='ami.mr', port=443): Read timed out. (read timeout=10)"))⚠ Error fetching body: https://ami.mr/fr/archives/33522 -> HTTPSConnectionPool(host='ami.mr', port=443): Max retries exceeded with url: /fr/archives/33522 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='ami.mr', port=443): Read timed out. (read timeout=10)"))
# ⚠ Error fetching body: https://ami.mr/fr/archives/33480 -> HTTPSConnectionPool(host='ami.mr', port=443): Max retries exceeded with url: /fr/archives/33480 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='ami.mr', port=443): Read timed out. (read timeout=10)"))
# ⚠ Error fetching body: https://ami.mr/fr/archives/33462 -> HTTPSConnectionPool(host='ami.mr', port=443): Max retries exceeded with url: /fr/archives/33462 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='ami.mr', port=443): Read timed out. (read timeout=10)"))
# ⚠ Error fetching body: https://ami.mr/fr/archives/33619 -> HTTPSConnectionPool(host='ami.mr', port=443): Max retries exceeded with url: /fr/archives/33619 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='ami.mr', port=443): Read timed out. (read timeout=10)"))
# ⚠ Error fetching body: https://ami.mr/fr/archives/33521 -> HTTPSConnectionPool(host='ami.mr', port=443): Max retries exceeded with url: /fr/archives/33521 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='ami.mr', port=443): Read timed out. (read timeout=10)"))
#
#
# 🔎 Scraping tag 'Politique' | page 224
# ➡ Fetching 10 article bodies...
#
# 🔎 Scraping tag 'Politique' | page 225
# ➡ Fetching 10 article bodies...
#
# 🔎 Scraping tag 'Politique' | page 226
# ➡ Fetching 10 article bodies...
#
# 🔎 Scraping tag 'Politique' | page 227
# ➡ Fetching 10 article bodies...
#
# 🔎 Scraping tag 'Politique' | page 228
# ➡ Fetching 10 article bodies...
#
# 🔎 Scraping tag 'Politique' | page 229
# ➡ Fetching 10 article bodies...
#
# 🔎 Scraping tag 'Politique' | page 230
# ➡ Fetching 10 article bodies...
#
# 🔎 Scraping tag 'Politique' | page 231
# ➡ Fetching 10 article bodies...
#
# 🔎 Scraping tag 'Politique' | page 232
# ➡ Fetching 10 article bodies...
#
# 🔎 Scraping tag 'Politique' | page 233
# ➡ Fetching 10 article bodies...
#
# 🔎 Scraping tag 'Politique' | page 234
# ➡ Fetching 10 article bodies...
#
# 🔎 Scraping tag 'Politique' | page 235
# ➡ Fetching 10 article bodies...
#
# 🔎 Scraping tag 'Politique' | page 236
# ➡ Fetching 10 article bodies...
#
# 🔎 Scraping tag 'Politique' | page 237
# ➡ Fetching 10 article bodies...
#
# 🔎 Scraping tag 'Politique' | page 238
# ➡ Fetching 10 article bodies...
#
# 🔎 Scraping tag 'Politique' | page 239
# ➡ Fetching 10 article bodies...
#
# 🔎 Scraping tag 'Politique' | page 240
# ➡ Fetching 10 article bodies...
#
# 🔎 Scraping tag 'Politique' | page 241
# ➡ Fetching 10 article bodies...
#
# 🔎 Scraping tag 'Politique' | page 242
# ➡ Fetching 10 article bodies...
#
# 🔎 Scraping tag 'Politique' | page 243
# ➡ Fetching 10 article bodies...
#
# 🔎 Scraping tag 'Politique' | page 244
# ➡ Fetching 10 article bodies...
#
# 🔎 Scraping tag 'Politique' | page 245
# ➡ Fetching 10 article bodies...
#
# 🔎 Scraping tag 'Politique' | page 246
# ➡ Fetching 10 article bodies...
#
# 🔎 Scraping tag 'Politique' | page 247
# ➡ Fetching 10 article bodies...
#
# 🔎 Scraping tag 'Politique' | page 248
# ➡ Fetching 10 article bodies...
# ⚠ Error fetching body: https://ami.mr/fr/archives/29097 -> HTTPSConnectionPool(host='ami.mr', port=443): Read timed out.
#
# 🔎 Scraping tag 'Politique' | page 249
# ➡ Fetching 10 article bodies...
#
# 🔎 Scraping tag 'Politique' | page 250
# ➡ Fetching 10 article bodies...
# ⚠ Error fetching body: https://ami.mr/fr/archives/28680 -> HTTPSConnectionPool(host='ami.mr', port=443): Read timed out.
# ⚠ Error fetching body: https://ami.mr/fr/archives/28693 -> HTTPSConnectionPool(host='ami.mr', port=443): Read timed out.
# ⚠ Error fetching body: https://ami.mr/fr/archives/28689 -> HTTPSConnectionPool(host='ami.mr', port=443): Read timed out.⚠ Error fetching body: https://ami.mr/fr/archives/28754 -> HTTPSConnectionPool(host='ami.mr', port=443): Read timed out.
#
# ⚠ Error fetching body: https://ami.mr/fr/archives/28593 -> HTTPSConnectionPool(host='ami.mr', port=443): Max retries exceeded with url: /fr/archives/28593 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='ami.mr', port=443): Read timed out. (read timeout=10)"))
#
# 🔎 Scraping tag 'Politique' | page 251
# ➡ Fetching 10 article bodies...
#
# 🔎 Scraping tag 'Politique' | page 252
# ➡ Fetching 10 article bodies...
#
# 🔎 Scraping tag 'Politique' | page 253
# ➡ Fetching 10 article bodies...
#
# 🔎 Scraping tag 'Politique' | page 254
# ➡ Fetching 10 article bodies...
#
# 🔎 Scraping tag 'Politique' | page 255
# ➡ Fetching 10 article bodies...
#
# 🔎 Scraping tag 'Politique' | page 256
# ➡ Fetching 10 article bodies...
#
# 🔎 Scraping tag 'Politique' | page 257
# ➡ Fetching 10 article bodies...
#
# 🔎 Scraping tag 'Politique' | page 258
# ➡ Fetching 10 article bodies...
#
# 🔎 Scraping tag 'Politique' | page 259
# ➡ Fetching 10 article bodies...
#
# 🔎 Scraping tag 'Politique' | page 260
# ➡ Fetching 10 article bodies...
#
# 🔎 Scraping tag 'Politique' | page 261
# ➡ Fetching 10 article bodies...
#
# 🔎 Scraping tag 'Politique' | page 262
# ➡ Fetching 10 article bodies...
#
# 🔎 Scraping tag 'Politique' | page 263
# ➡ Fetching 10 article bodies...
# ⚠ Error fetching body: https://ami.mr/fr/archives/26136 -> HTTPSConnectionPool(host='ami.mr', port=443): Max retries exceeded with url: /fr/archives/26136 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='ami.mr', port=443): Read timed out. (read timeout=10)"))
# ⚠ Error fetching body: https://ami.mr/fr/archives/26084 -> HTTPSConnectionPool(host='ami.mr', port=443): Max retries exceeded with url: /fr/archives/26084 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='ami.mr', port=443): Read timed out. (read timeout=10)"))
# ⚠ Error fetching body: https://ami.mr/fr/archives/26080 -> HTTPSConnectionPool(host='ami.mr', port=443): Max retries exceeded with url: /fr/archives/26080 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='ami.mr', port=443): Read timed out. (read timeout=10)"))
# ⚠ Error fetching body: https://ami.mr/fr/archives/26131 -> HTTPSConnectionPool(host='ami.mr', port=443): Max retries exceeded with url: /fr/archives/26131 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='ami.mr', port=443): Read timed out. (read timeout=10)"))
# ⚠ Error fetching body: https://ami.mr/fr/archives/26115 -> HTTPSConnectionPool(host='ami.mr', port=443): Max retries exceeded with url: /fr/archives/26115 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='ami.mr', port=443): Read timed out. (read timeout=10)"))
# ⚠ Error fetching body: https://ami.mr/fr/archives/26132 -> HTTPSConnectionPool(host='ami.mr', port=443): Max retries exceeded with url: /fr/archives/26132 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='ami.mr', port=443): Read timed out. (read timeout=10)"))
# ⚠ Error fetching body: https://ami.mr/fr/archives/26072 -> HTTPSConnectionPool(host='ami.mr', port=443): Max retries exceeded with url: /fr/archives/26072 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='ami.mr', port=443): Read timed out. (read timeout=10)"))
# ⚠ Error fetching body: https://ami.mr/fr/archives/26112 -> HTTPSConnectionPool(host='ami.mr', port=443): Max retries exceeded with url: /fr/archives/26112 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='ami.mr', port=443): Read timed out. (read timeout=10)"))
# ⚠ Error fetching body: https://ami.mr/fr/archives/26104 -> HTTPSConnectionPool(host='ami.mr', port=443): Max retries exceeded with url: /fr/archives/26104 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='ami.mr', port=443): Read timed out. (read timeout=10)"))
#
# 🔎 Scraping tag 'Politique' | page 264
# ⚠ Request error on page 264: HTTPSConnectionPool(host='ami.mr', port=443): Max retries exceeded with url: /fr/archives/tag/politique/page/264 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='ami.mr', port=443): Read timed out. (read timeout=10)"))
#
# 🔎 Scraping tag 'Politique' | page 264
# ⚠ Request error on page 264: HTTPSConnectionPool(host='ami.mr', port=443): Max retries exceeded with url: /fr/archives/tag/politique/page/264 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='ami.mr', port=443): Read timed out. (read timeout=10)"))
#
# 🔎 Scraping tag 'Politique' | page 264
# ⚠ Request error on page 264: HTTPSConnectionPool(host='ami.mr', port=443): Max retries exceeded with url: /fr/archives/tag/politique/page/264 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='ami.mr', port=443): Read timed out. (read timeout=10)"))
#
# 🔎 Scraping tag 'Politique' | page 264
# ⚠ Request error on page 264: HTTPSConnectionPool(host='ami.mr', port=443): Max retries exceeded with url: /fr/archives/tag/politique/page/264 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='ami.mr', port=443): Read timed out. (read timeout=10)"))
#
# 🔎 Scraping tag 'Politique' | page 264
# ⚠ Request error on page 264: HTTPSConnectionPool(host='ami.mr', port=443): Max retries exceeded with url: /fr/archives/tag/politique/page/264 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='ami.mr', port=443): Read timed out. (read timeout=10)"))
#
# 🔎 Scraping tag 'Politique' | page 264
# ⚠ Request error on page 264: HTTPSConnectionPool(host='ami.mr', port=443): Max retries exceeded with url: /fr/archives/tag/politique/page/264 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='ami.mr', port=443): Read timed out. (read timeout=10)"))
#
# 🔎 Scraping tag 'Politique' | page 264
# ⚠ Request error on page 264: HTTPSConnectionPool(host='ami.mr', port=443): Max retries exceeded with url: /fr/archives/tag/politique/page/264 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='ami.mr', port=443): Read timed out. (read timeout=10)"))
#
# 🔎 Scraping tag 'Politique' | page 264
# ⚠ Request error on page 264: HTTPSConnectionPool(host='ami.mr', port=443): Max retries exceeded with url: /fr/archives/tag/politique/page/264 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='ami.mr', port=443): Read timed out. (read timeout=10)"))
#
# 🔎 Scraping tag 'Politique' | page 264
# ⚠ Request error on page 264: HTTPSConnectionPool(host='ami.mr', port=443): Max retries exceeded with url: /fr/archives/tag/politique/page/264 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='ami.mr', port=443): Read timed out. (read timeout=10)"))
#
# 🔎 Scraping tag 'Politique' | page 264
# ➡ Fetching 10 article bodies...
#
# 🔎 Scraping tag 'Politique' | page 265
# ➡ Fetching 10 article bodies...
#
# 🔎 Scraping tag 'Politique' | page 266
# ➡ Fetching 10 article bodies...
#
# 🔎 Scraping tag 'Politique' | page 267
# ➡ Fetching 10 article bodies...
# ⚠ Error fetching body: https://ami.mr/fr/archives/25387 -> HTTPSConnectionPool(host='ami.mr', port=443): Max retries exceeded with url: /fr/archives/25387 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='ami.mr', port=443): Read timed out. (read timeout=10)"))
# ⚠ Error fetching body: https://ami.mr/fr/archives/25215 -> HTTPSConnectionPool(host='ami.mr', port=443): Max retries exceeded with url: /fr/archives/25215 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='ami.mr', port=443): Read timed out. (read timeout=10)"))⚠ Error fetching body: https://ami.mr/fr/archives/25344 -> HTTPSConnectionPool(host='ami.mr', port=443): Max retries exceeded with url: /fr/archives
# ➡ Fetching 10 article bodies...
#
# 🔎 Scraping tag 'Politique' | page 882
# ➡ Fetching 10 article bodies...
#
# 🔎 Scraping tag 'Politique' | page 883
# ➡ Fetching 10 article bodies...
#
# 🔎 Scraping tag 'Politique' | page 884
# ➡ Fetching 10 article bodies...
#
# 🔎 Scraping tag 'Politique' | page 885
# ➡ Fetching 10 article bodies...
#
# 🔎 Scraping tag 'Politique' | page 886
# ➡ Fetching 10 article bodies...
#
# 🔎 Scraping tag 'Politique' | page 887
# ➡ Fetching 10 article bodies...
#
# 🔎 Scraping tag 'Politique' | page 888
# ➡ Fetching 10 article bodies...
#
# 🔎 Scraping tag 'Politique' | page 889
# ➡ Fetching 10 article bodies...
#
# 🔎 Scraping tag 'Politique' | page 890
# ➡ Fetching 10 article bodies...
#
# 🔎 Scraping tag 'Politique' | page 891
# ➡ Fetching 10 article bodies...
#
# 🔎 Scraping tag 'Politique' | page 892
# ➡ Fetching 10 article bodies...
#
# 🔎 Scraping tag 'Politique' | page 893
# ➡ Fetching 10 article bodies...
#
# 🔎 Scraping tag 'Politique' | page 894
# ➡ Fetching 10 article bodies...
#
# 🔎 Scraping tag 'Politique' | page 895
# ➡ Fetching 10 article bodies...
#
# 🔎 Scraping tag 'Politique' | page 896
# ➡ Fetching 10 article bodies...
#
# 🔎 Scraping tag 'Politique' | page 897
# ➡ Fetching 10 article bodies...
#
# 🔎 Scraping tag 'Politique' | page 898
# ➡ Fetching 10 article bodies...
#
# 🔎 Scraping tag 'Politique' | page 899
# ➡ Fetching 10 article bodies...
#
# 🔎 Scraping tag 'Politique' | page 900
# ➡ Fetching 10 article bodies...
#
# 🔎 Scraping tag 'Politique' | page 901
# ➡ Fetching 10 article bodies...
#
# 🔎 Scraping tag 'Politique' | page 902
# ➡ Fetching 10 article bodies...
#
# 🔎 Scraping tag 'Politique' | page 903
# ➡ Fetching 10 article bodies...
#
# 🔎 Scraping tag 'Politique' | page 904
# ➡ Fetching 10 article bodies...
#
# 🔎 Scraping tag 'Politique' | page 905
# ➡ Fetching 2 article bodies...
#
# 🔎 Scraping tag 'Politique' | page 906
# ✔ No more pages. Stopping.
#
# ✅ Saved: ami_Tag_politique_2022-08-06_to_2007-01-01.csv
# 📌 Total articles scraped: 9042

# %%
# upload csv file
import pandas as pd
df= pd.read_csv("ami_Tag_politique_2022-08-06_to_2007-01-01.csv")
df
# Out:
#             tag                                              title  \
# 0     Politique  Les partis de la majorité commémorent le trois...
# 1     Politique  La présidente du Conseil régional de Nouakchot...
# 2     Politique  Célébration de la journée mondiale de lutte co...
# 3     Politique  Le ministre de l’Equipement et des Transports ...
# 4     Politique  Sélibabi : Atelier pour la coordination entre ...
# ...         ...                                                ...
# 9037  Politique             Début des opérations du Ravel en Adrar
# 9038  Politique  Atar: Validation de 15 listes candidates aux s...
# 9039  Politique                           Début du Ravel au Trarza
# 9040  Politique                Réunion du Bureau Exécutif de l’UCD
# 9041  Politique  Début des opération du Ravel III au Hodh El Gh...
#
#                                     url                   datetime  \
# 0     https://ami.mr/fr/archives/203122  2022-08-06 19:13:39+00:00
# 1     https://ami.mr/fr/archives/202418  2022-07-30 23:21:33+00:00
# 2     https://ami.mr/fr/archives/202417  2022-07-30 23:18:52+00:00
# 3     https://ami.mr/fr/archives/202174  2022-07-24 21:14:53+00:00
# 4     https://ami.mr/fr/archives/202094  2022-07-21 19:24:11+00:00
# ...                                 ...                        ...
# 9037    https://ami.mr/fr/archives/1075  2007-01-02 11:00:00+00:00
# 9038    https://ami.mr/fr/archives/1074  2007-01-02 10:00:00+00:00
# 9039    https://ami.mr/fr/archives/1072  2007-01-02 09:00:00+00:00
# 9040    https://ami.mr/fr/archives/1070  2007-01-02 08:00:00+00:00
# 9041    https://ami.mr/fr/archives/1068  2007-01-01 14:00:00+00:00
#
#                                                 summary  \
# 0     Les partis de la majorité ont commémoré, vendr...
# 1     La présidente du Conseil régional de Nouakchot...
# 2     Le Commissaire adjoint aux droits de l'homme, ...
# 3     Le ministre de l'Equipement et des Transports,...
# 4     Un atelier associant autorités locales, comité...
# ...                                                 ...
# 9037  Le Wali de l'Adrar, M. Mohamed Ould Mohamed Sa...
# 9038  La commission administrative chargée de la val...
# 9039  Les opérations du recensement administratif à ...
# 9040  Le Bureau exécutif national du parti de l'Unio...
# 9041  Les opérations du troisième recensement admini...
#
#                                            article_body
# 0     Les partis de la majorité ont commémoré, vendr...
# 1     La présidente du Conseil régional de Nouakchot...
# 2     Le Commissaire adjoint aux droits de l’homme, ...
# 3     Le ministre de l’Equipement et des Transports,...
# 4     Un atelier associant autorités locales, comité...
# ...                                                 ...
# 9037  Le Wali de l’Adrar, M. Mohamed Ould Mohamed Sa...
# 9038  La commission administrative chargée de la val...
# 9039  Les opérations du recensement administratif à ...
# 9040  Le Bureau exécutif national du parti de l’Unio...
# 9041  Les opérations du troisième recensement admini...
#
# [9042 rows x 6 columns]

# %%
# read json file
df_json = pd.read_json("articles_mauritanie.json")
df_json
# Out:
#             tag                                              title  \
# 0     Politique  Les partis de la majorité commémorent le trois...
# 1     Politique  La présidente du Conseil régional de Nouakchot...
# 2     Politique  Célébration de la journée mondiale de lutte co...
# 3     Politique  Le ministre de l’Equipement et des Transports ...
# 4     Politique  Sélibabi : Atelier pour la coordination entre ...
# ...         ...                                                ...
# 9037  Politique             Début des opérations du Ravel en Adrar
# 9038  Politique  Atar: Validation de 15 listes candidates aux s...
# 9039  Politique                           Début du Ravel au Trarza
# 9040  Politique                Réunion du Bureau Exécutif de l’UCD
# 9041  Politique  Début des opération du Ravel III au Hodh El Gh...
#
#                                     url                  datetime  \
# 0     https://ami.mr/fr/archives/203122 2022-08-06 19:13:39+00:00
# 1     https://ami.mr/fr/archives/202418 2022-07-30 23:21:33+00:00
# 2     https://ami.mr/fr/archives/202417 2022-07-30 23:18:52+00:00
# 3     https://ami.mr/fr/archives/202174 2022-07-24 21:14:53+00:00
# 4     https://ami.mr/fr/archives/202094 2022-07-21 19:24:11+00:00
# ...                                 ...                       ...
# 9037    https://ami.mr/fr/archives/1075 2007-01-02 11:00:00+00:00
# 9038    https://ami.mr/fr/archives/1074 2007-01-02 10:00:00+00:00
# 9039    https://ami.mr/fr/archives/1072 2007-01-02 09:00:00+00:00
# 9040    https://ami.mr/fr/archives/1070 2007-01-02 08:00:00+00:00
# 9041    https://ami.mr/fr/archives/1068 2007-01-01 14:00:00+00:00
#
#                                                 summary  \
# 0     Les partis de la majorité ont commémoré, vendr...
# 1     La présidente du Conseil régional de Nouakchot...
# 2     Le Commissaire adjoint aux droits de l'homme, ...
# 3     Le ministre de l'Equipement et des Transports,...
# 4     Un atelier associant autorités locales, comité...
# ...                                                 ...
# 9037  Le Wali de l'Adrar, M. Mohamed Ould Mohamed Sa...
# 9038  La commission administrative chargée de la val...
# 9039  Les opérations du recensement administratif à ...
# 9040  Le Bureau exécutif national du parti de l'Unio...
# 9041  Les opérations du troisième recensement admini...
#
#                                            article_body
# 0     Les partis de la majorité ont commémoré, vendr...
# 1     La présidente du Conseil régional de Nouakchot...
# 2     Le Commissaire adjoint aux droits de l’homme, ...
# 3     Le ministre de l’Equipement et des Transports,...
# 4     Un atelier associant autorités locales, comité...
# ...                                                 ...
# 9037  Le Wali de l’Adrar, M. Mohamed Ould Mohamed Sa...
# 9038  La commission administrative chargée de la val...
# 9039  Les opérations du recensement administratif à ...
# 9040  Le Bureau exécutif national du parti de l’Unio...
# 9041  Les opérations du troisième recensement admini...
#
# [9042 rows x 6 columns]
